# %% [markdown]
# #### FB Graph API
# #### HTTP states(Cookies, Sessions)
# ##### Example:
# 1. PTT
#
# ### Review and Concusion: HTTP and the web
#
# #### Selenium
# #### Common transformations(Datetime, numbers, strings)
# #### Regular expression

# %%
# FB Graph API
import requests

res = requests.get("https://graph.facebook.com/v2.9/1068531466501015/feed", params={
    "access_token": "EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD",
    "fields": "message,comments.limit(500).sort(reverse_chronological),attachments",
    "limit": 20
})

# %%
res.status_code
# Out:
# 200

# %%
res.json().keys()
# Out:
# dict_keys(['data', 'paging'])

# %%
res.json()['paging']
# Out:
# {'next': 'https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499216204&__paging_token=enc_AdDVh6gNl0MCgZCqZAZAc9k0Qdi93ksEx2WgvZBys2wKoKVBM4SRSmBs7dYkpEtWjZAdfF5gJXIZBxcPOYZCZAE8jcr1E4lhv2mUcjf6XHuZBMoGt1m0IqQZDZD',
#  'previous': 'https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&icon_size=16&since=1499217159&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&__paging_token=enc_AdAvZBSNSZBq7BKOgaxH11Hh4k4ZCei6C5saCniqnNeZCuZBiuVw79jwCSlNSc2IXjSyaAgwCFBMkUXUIA8vphM4uBiZA4T43IBZABrkCIIhZA8OkJh0ZCQZDZD&__previous=1'}

# %%
while True:
    next_url = res.json()['paging']['next']
    print("[INFO] crawling %s"%next_url)
    res = requests.get(next_url)
    print("[INFO] %s finished"%next_url)
    with open('fb_%s.json'%(res.json()['paging']['next'].split('until=')[1].split('&__pag')[0]), 'w') as f:
        f.write(res.text)
# Out:
# [INFO] crawling https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_AdA2jldOjdHSA5nRirTBwAdXH34y8WeoRfisbi6iiDFxpc0cnm10NW5N9L0N6Sw3pDCiTlocRiSAZCr53Nu8bZBDfrUzpeZCK8cae9kuhcoouTE5QZDZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499214026
# [INFO] https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_AdA2jldOjdHSA5nRirTBwAdXH34y8WeoRfisbi6iiDFxpc0cnm10NW5N9L0N6Sw3pDCiTlocRiSAZCr53Nu8bZBDfrUzpeZCK8cae9kuhcoouTE5QZDZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499214026 finished
# [INFO] crawling https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_AdAegLQYnJsJZAHAm0csAYMd8gG3QIkZA1ZCrgsblFHQwqQxkHGf7cTTgJPzIystezpZAEXqPZAcBpOSZAnMZAs9uxG6i38E16oe9c8KKYNEOLNOWmdxAZDZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499211316
# [INFO] https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_AdAegLQYnJsJZAHAm0csAYMd8gG3QIkZA1ZCrgsblFHQwqQxkHGf7cTTgJPzIystezpZAEXqPZAcBpOSZAnMZAs9uxG6i38E16oe9c8KKYNEOLNOWmdxAZDZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499211316 finished
# [INFO] crawling https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_AdDwroOYV4ZBd6bavqVyTqpU0qRrs0hvCgRIsy55L79zVIDeUJtJmRhuiSpkeO04DCFCPc4aFAcuo4htUZCjseoChphDBBPDlUZClZAeoweMXSc84QZDZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499208910
# [INFO] https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_AdDwroOYV4ZBd6bavqVyTqpU0qRrs0hvCgRIsy55L79zVIDeUJtJmRhuiSpkeO04DCFCPc4aFAcuo4htUZCjseoChphDBBPDlUZClZAeoweMXSc84QZDZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499208910 finished
# [INFO] crawling https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_A
DZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499145843 finished
# [INFO] crawling https://graph.facebook.com/v2.9/1068531466501015/feed?fields=message,comments.limit%28500%29.sort%28reverse_chronological%29,attachments&limit=20&__paging_token=enc_AdA8PPvHik7WWfXeNynZAe4ka2hiWDURBgqAhIZCtjzNauJ1U6HKPvg42jG17sXQq830ml2nYCxDsDmXZARTOJ9t1PHLnZA7F3zwguN5oV4s3voOZAQZDZD&icon_size=16&access_token=EAACEdEose0cBAKsB75S34ME72rTZBQR41YZB2fZCdpdQ7ZAqNBaEtSKRHHeJ6PvIYSO7Esx36Pz3G1WhQ0qW0BtKyXdHST7ZCfC6sGo8TwDVtFcufQjZCkyi49QSnTPyc475tW9eTuC2raZCLDQitHUHDEqQrqbaZC0zYkZAqrLy3FcmyBsJBGZAKGDwokKcDStxMZD&until=1499137508
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-63d979b03638> in <module>()
#       2     next_url = res.json()['paging']['next']
#       3     print("[INFO] crawling %s"%next_url)
# ----> 4     res = requests.get(next_url)
#       5     print("[INFO] %s finished"%next_url)
#       6     with open('fb_%s.json'%(res.json()['paging']['next'].split('until=')[1].split('&__pag')[0]), 'w') as f:
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     500         }
#     501         send_kwargs.update(settings)
# --> 502         resp = self.send(prep, **send_kwargs)
#     503
#     504         return resp
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     610
#     611         # Send the request
# --> 612         r = adapter.send(request, **kwargs)
#     613
#     614         # Total elapsed time of the request (approximately)
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1000                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#    1004             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/ssl.py in read(self, len, buffer)
#     863             raise ValueError("Read on closed or unwrapped SSL socket.")
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#     867             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/ssl.py in read(self, len, buffer)
#     623         """
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#     627             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !ls
# Out:
# cai_speech.txt            fb_1499166382.json        fb_1499205080.json
# dict.txt.big              fb_1499173547.json        fb_1499208910.json
# dict.txt.big.1            fb_1499177953.json        fb_1499211316.json
# donal_trump.txt           fb_1499181702.json        python_etl_20170627.ipynb
# donald_trump.txt          fb_1499186451.json        python_etl_20170629.ipynb
# fb_1498720637.json        fb_1499191283.json        python_etl_20170705.ipynb
# fb_1499137508.json        fb_1499194783.json        speech.txt
# fb_1499145843.json        fb_1499197931.json        tomamu.html
# fb_1499159082.json        fb_1499201278.json

# %%
import json

fb_data = json.load(open('./fb_1498720637.json'))

# %%
type(fb_data)
# Out:
# dict

# %% [markdown]
# # HTTP State management

# %%
# PTT
import requests

URL = "https://www.ptt.cc/bbs/Gossiping"
res = requests.get(URL)
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>

# %%
res.request.headers
# Out:
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '__cfduid=d46117ecf630dba6554eca4d0443a33db1499219075'}

# %%
# PTT
import requests

URL = "https://www.ptt.cc/bbs/Gossiping/index.html"
res = requests.get(URL, headers={"cookie": "over18=1;"})
print(res.text)
res.request.headers
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index25315.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219295.A.201.html">Re: [新聞] 幫經商老爸種出市值1億大麻！政大外交畢</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">songgood</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219339.A.8E7.html">[問卦] 有沒有辦不成手機就不當人的八卦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">Salcea</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219432.A.F24.html">Re: [爆卦] 最新大臺北各地區所得排名</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">BorrasH</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219486.A.F1F.html">[問卦] 萬丹黑煙下的鵝怎麼辦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">kari55</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219541.A.BD6.html">[問卦] 有沒有國家工具人 短期約僱人員的掛</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">s880801w</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219569.A.93E.html">[問卦] 被垃圾老師當掉怎麼辦？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">xxxgg5566</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219610.A.EFD.html">[新聞] 花蓮五子命案凶宅入厝…新屋主「睡得安</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">TSFU</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219625.A.C2F.html">[問卦] 要開始造神計畫了嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">johnnywanwan</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">21</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498033253.A.548.html">[協尋]市民大道五段 7:30 車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/21</div>
# 				<div class="author">Kimg</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498120174.A.818.html">[協尋]6/5宜蘭往礁溪林美一帶走失</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/22</div>
# 				<div class="author">lemondrink46</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">23</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498656193.A.C9B.html">[協尋]6/28傍晚17:30左右辛亥路木柵路口行車影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/28</div>
# 				<div class="author">jessicaY</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark">!</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1497542802.A.EC6.html">[公告] 八卦板板規(2017.06.16)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/16</div>
# 				<div class="author">Mews</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">98</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498840923.A.DB6.html">[公告] 七月份置底閒聊區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/01</div>
# 				<div class="author">Mews</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'cookie': 'over18=1;'}

# %%
# PTT
import requests

URL = "https://www.ptt.cc/bbs/Gossiping/index.html"
res = requests.get(URL, cookies={"over18": "1"})
print(res.text)
res.request.headers
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index25315.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219295.A.201.html">Re: [新聞] 幫經商老爸種出市值1億大麻！政大外交畢</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">songgood</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219339.A.8E7.html">[問卦] 有沒有辦不成手機就不當人的八卦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">Salcea</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219432.A.F24.html">Re: [爆卦] 最新大臺北各地區所得排名</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">BorrasH</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219486.A.F1F.html">[問卦] 萬丹黑煙下的鵝怎麼辦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">kari55</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219541.A.BD6.html">[問卦] 有沒有國家工具人 短期約僱人員的掛</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">s880801w</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219569.A.93E.html">[問卦] 被垃圾老師當掉怎麼辦？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">xxxgg5566</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219610.A.EFD.html">[新聞] 花蓮五子命案凶宅入厝…新屋主「睡得安</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">TSFU</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219625.A.C2F.html">[問卦] 要開始造神計畫了嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">johnnywanwan</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219644.A.1F8.html">Re: [新聞] 勁爆！三立老董林崑海　載女議員上摩鐵</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">hitolin</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219679.A.795.html">[新聞] 桌邪又亂搞</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">pompyee</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1499219750.A.CCA.html">[問卦] 怎樣算講幹話？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/05</div>
# 				<div class="author">qwqa</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">21</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498033253.A.548.html">[協尋]市民大道五段 7:30 車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/21</div>
# 				<div class="author">Kimg</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498120174.A.818.html">[協尋]6/5宜蘭往礁溪林美一帶走失</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/22</div>
# 				<div class="author">lemondrink46</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">23</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498656193.A.C9B.html">[協尋]6/28傍晚17:30左右辛亥路木柵路口行車影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/28</div>
# 				<div class="author">jessicaY</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark">!</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1497542802.A.EC6.html">[公告] 八卦板板規(2017.06.16)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/16</div>
# 				<div class="author">Mews</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">98</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1498840923.A.DB6.html">[公告] 七月份置底閒聊區</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/01</div>
# 				<div class="author">Mews</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>
#
#     </body>
# </html>
# {'User-Agent': 'python-requests/2.18.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'over18=1'}

# %%
# Server side state
# pcc
