# %%
# More selenium/splinter examples
import time

import splinter

# %%
browser = splinter.Browser('chrome')

# %%
agoda_sapporo = "https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx?city=3435&pagetypeid=103&origin=TW&cid=-1&tag=&gclid=&aid=130243&userId=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8&languageId=1&sessionId=pmfnpqlgzwwhftausi1uzc3w&storefrontId=3&currencyCode=TWD&htmlLanguage=en-us&trafficType=User&cultureInfoName=en-US&checkIn=2018-01-12&checkOut=2018-01-22&los=10&rooms=1&adults=2&children=0&childages=&ckuid=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8&priceCur=TWD&hotelReviewScore=5"

browser.visit(agoda_sapporo)

# %%
scrollHeight = browser.evaluate_script("document.body.scrollHeight")
print(scrollHeight)
# Out:
# 9777

# %%
step = 10
for i in range(1,step+1):
    browser.execute_script("window.scrollTo(0,%s)"%(scrollHeight*i/step))
    time.sleep(1)

# %%
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
pg = 1
with open('sapporo_%s.html'%pg, 'w') as f:
    f.write(browser.html)

# %%
if browser.is_element_visible_by_css("#paginationNext"):
    browser.click_link_by_id("paginationNext")
else:
    print("[END]")
# Out:
# [END]

# %%
browser.cookies.all()
# Out:
# {'ASP.NET_SessionId': 'cthv3ir2ugaa02lslovkkfgb',
#  'UserSession': 'd7d3ca0c-3f28-4a87-aca3-d8d27dcf326e',
#  '_40-40-20Split': 'Group40A',
#  '_ab50group': 'GroupB',
#  '_ga': 'GA1.2.2039112362.1503540439',
#  '_gid': 'GA1.2.1922229573.1503540439',
#  'agoda.allclicks': '-1||||2017-08-24T09:17:52||cthv3ir2ugaa02lslovkkfgb||{"IsPaid":false,"gclid":"","Type":"LC"}',
#  'agoda.attr.01': 'CookieId=923d1fac-ff63-447d-bcad-c4e9cf3b649c',
#  'agoda.attr.03': 'CookieId=4709b7ae-9260-4869-b9b2-5de5de0651e1',
#  'agoda.firstclicks': '-1||||2017-08-24T09:07:14||cthv3ir2ugaa02lslovkkfgb||{"IsPaid":false,"gclid":"","Type":""}',
#  'agoda.lastclicks': '-1||||2017-08-24T09:07:14||cthv3ir2ugaa02lslovkkfgb||{"IsPaid":false,"gclid":"","Type":""}',
#  'agoda.prius': 'PriusID=0&PointsMaxTraffic=Agoda',
#  'agoda.search.01': 'SHist=1$3435$6220$10$1$2$0$0$$&H=',
#  'agoda.user.03': 'UserId=d7d3ca0c-3f28-4a87-aca3-d8d27dcf326e',
# ...

# %%
browser.quit()

# %%
# CNYES crawler
import urllib.parse

import requests as r

URL = "http://news.cnyes.com/api/v2/news?limit=30&startAt=1502640000&endAt=1503590399&page=1"

res = r.get(URL)

# %%
cnyes_list = ["http://news.cnyes.com/news/id/%s"%doc['newsId'] for doc in res.json()['items']['data']]

# %%
# !mkdir cnyes_data

# %%
for link in cnyes_list:
    with open('./cnyes_data/%s.html'%(urllib.parse.quote_plus(link)), 'w') as f:
        f.write(r.get(link).text)

# %%
cnyes_list[0]
# Out:
# 'http://news.cnyes.com/news/id/3900599'

# %%
urllib.parse.quote_plus(cnyes_list[0])
# Out:
# 'http%3A%2F%2Fnews.cnyes.com%2Fnews%2Fid%2F3900599'

# %%
with open('./cnyes_data/' + urllib.parse.quote_plus(cnyes_list[0]) + '.html') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html5lib')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.select("main > h1 > span")
# Out:
# [<span class="_uo1" data-reactid="217" itemprop="headline">法國恐攻太多 香奈兒好受傷 去年淨利潤跌掉35%</span>]

# %%
soup.select("main > h1 > span")[0]
# Out:
# <span class="_uo1" data-reactid="217" itemprop="headline">法國恐攻太多 香奈兒好受傷 去年淨利潤跌掉35%</span>

# %%
soup.select("main > h1 > span")[0].text
# Out:
# '法國恐攻太多 香奈兒好受傷 去年淨利潤跌掉35%'

# %%
soup.select_one("main > h1 > span").text
# Out:
# '法國恐攻太多 香奈兒好受傷 去年淨利潤跌掉35%'

# %%
soup.select_one("main > h1 > div > time").text
# Out:
# '2017/08/24 10:55'

# %%
# Dictionary gracefully query
# Return None, if key does not exist

contacts = [{"name": "ian",
              "mail": "ian@gmail.com"},
             {"mail": "david@gmail.com"}]
contacts
# Out:
# [{'mail': 'ian@gmail.com', 'name': 'ian'}, {'mail': 'david@gmail.com'}]

# %%
for person in contacts:
    print(person['name'])
# Out:
# ian
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-d97eb28be902> in <module>()
#       1 for person in contacts:
# ----> 2     print(person['name'])
#
# KeyError: 'name'

# %%
for person in contacts:
    print(person.get('name'))
# Out:
# ian
# None

# %%
# None is a falsy value,
if None:
    print("ok")
else:
    print("hi")
# Out:
# hi

# %%
soup.find_all(lambda x: x.get('itemprop') == 'articleBody')
# Out:
# [<div data-reactid="243" itemprop="articleBody"><p>奢侈品的指標品牌香奈兒 Chanel 已經連續兩年銷售、淨利雙跌，根據法國媒體 Le Monde 最新消息，Chanel 已經向荷蘭阿姆斯特丹工商部門遞交 2016 年全年財務報告，數據顯示，Chanel 銷售額為 56.7 億美元，較前一年大跌 9%；營業利潤為 12.8 億美元，同比下跌 20%；淨利潤為 8.74 億美元，同比下跌 35%。</p>
#
#  <p>業績不佳，Chanel 指出，是因為去 (2016) 年歐洲在法國恐怖攻擊頻傳，讓當地旅遊業疲軟、消費者購物慾望低迷；此外一部分原因為 Chanel 去年將旗下英國子公司 Chanel Limited UK 出售的緣故。</p>
#
#  <p>時尚頭條網指出，2015 年開始， Chanel 就面臨業績挑戰，在 2015 年全年報， Chanel 營業利潤為 16 億美元，下滑 23%；總銷售額 62.4 億美元，下滑 17%。而占據大多利潤的化妝品跟香水，20105 年銷售額為 29.1 億美元，同比下滑 21%。報導指出，2015 年歐洲恐怖攻擊等安全問題的確讓歐洲奢侈品行業壟罩在陰影中，然而有分析師指出， Chanel 集團的獲利金雞母，化妝品跟香水業務下跌，就是該集團的警訊。</p>
#
#  <p>北京商報報導，財富研究院院長周婷分析，消費者消費理念轉變很快，然而許多傳統的奢侈品品牌卻沒有跟上變革，老客戶流失的同時，新客戶進入速度也正在減緩，越是一線大牌業績下滑的速度就越快。過去幾年，部分奢侈品牌大舉擴張中國市場，門市覆蓋到一線、二線三線城市，然而快速擴張在某些程度上，等同損害品牌溢價跟稀有性。</p>
#  <hr style="height: 0; border-width: 1px; visibility: hidden"/></div>]

# %%
soup.find_all('div', attrs={
    'itemprop': 'articleBody'
})
# Out:
# [<div data-reactid="243" itemprop="articleBody"><p>奢侈品的指標品牌香奈兒 Chanel 已經連續兩年銷售、淨利雙跌，根據法國媒體 Le Monde 最新消息，Chanel 已經向荷蘭阿姆斯特丹工商部門遞交 2016 年全年財務報告，數據顯示，Chanel 銷售額為 56.7 億美元，較前一年大跌 9%；營業利潤為 12.8 億美元，同比下跌 20%；淨利潤為 8.74 億美元，同比下跌 35%。</p>
#
#  <p>業績不佳，Chanel 指出，是因為去 (2016) 年歐洲在法國恐怖攻擊頻傳，讓當地旅遊業疲軟、消費者購物慾望低迷；此外一部分原因為 Chanel 去年將旗下英國子公司 Chanel Limited UK 出售的緣故。</p>
#
#  <p>時尚頭條網指出，2015 年開始， Chanel 就面臨業績挑戰，在 2015 年全年報， Chanel 營業利潤為 16 億美元，下滑 23%；總銷售額 62.4 億美元，下滑 17%。而占據大多利潤的化妝品跟香水，20105 年銷售額為 29.1 億美元，同比下滑 21%。報導指出，2015 年歐洲恐怖攻擊等安全問題的確讓歐洲奢侈品行業壟罩在陰影中，然而有分析師指出， Chanel 集團的獲利金雞母，化妝品跟香水業務下跌，就是該集團的警訊。</p>
#
#  <p>北京商報報導，財富研究院院長周婷分析，消費者消費理念轉變很快，然而許多傳統的奢侈品品牌卻沒有跟上變革，老客戶流失的同時，新客戶進入速度也正在減緩，越是一線大牌業績下滑的速度就越快。過去幾年，部分奢侈品牌大舉擴張中國市場，門市覆蓋到一線、二線三線城市，然而快速擴張在某些程度上，等同損害品牌溢價跟稀有性。</p>
#  <hr style="height: 0; border-width: 1px; visibility: hidden"/></div>]

# %%
soup.find('div', attrs={
    'itemprop': 'articleBody'
})
# Out:
# <div data-reactid="243" itemprop="articleBody"><p>奢侈品的指標品牌香奈兒 Chanel 已經連續兩年銷售、淨利雙跌，根據法國媒體 Le Monde 最新消息，Chanel 已經向荷蘭阿姆斯特丹工商部門遞交 2016 年全年財務報告，數據顯示，Chanel 銷售額為 56.7 億美元，較前一年大跌 9%；營業利潤為 12.8 億美元，同比下跌 20%；淨利潤為 8.74 億美元，同比下跌 35%。</p>
#
# <p>業績不佳，Chanel 指出，是因為去 (2016) 年歐洲在法國恐怖攻擊頻傳，讓當地旅遊業疲軟、消費者購物慾望低迷；此外一部分原因為 Chanel 去年將旗下英國子公司 Chanel Limited UK 出售的緣故。</p>
#
# <p>時尚頭條網指出，2015 年開始， Chanel 就面臨業績挑戰，在 2015 年全年報， Chanel 營業利潤為 16 億美元，下滑 23%；總銷售額 62.4 億美元，下滑 17%。而占據大多利潤的化妝品跟香水，20105 年銷售額為 29.1 億美元，同比下滑 21%。報導指出，2015 年歐洲恐怖攻擊等安全問題的確讓歐洲奢侈品行業壟罩在陰影中，然而有分析師指出， Chanel 集團的獲利金雞母，化妝品跟香水業務下跌，就是該集團的警訊。</p>
#
# <p>北京商報報導，財富研究院院長周婷分析，消費者消費理念轉變很快，然而許多傳統的奢侈品品牌卻沒有跟上變革，老客戶流失的同時，新客戶進入速度也正在減緩，越是一線大牌業績下滑的速度就越快。過去幾年，部分奢侈品牌大舉擴張中國市場，門市覆蓋到一線、二線三線城市，然而快速擴張在某些程度上，等同損害品牌溢價跟稀有性。</p>
# <hr style="height: 0; border-width: 1px; visibility: hidden"/></div>

# %%
soup.find('div', attrs={
    'itemprop': 'articleBody'
}).text
# Out:
# '奢侈品的指標品牌香奈兒 Chanel 已經連續兩年銷售、淨利雙跌，根據法國媒體 Le Monde 最新消息，Chanel 已經向荷蘭阿姆斯特丹工商部門遞交 2016 年全年財務報告，數據顯示，Chanel 銷售額為 56.7 億美元，較前一年大跌 9%；營業利潤為 12.8 億美元，同比下跌 20%；淨利潤為 8.74 億美元，同比下跌 35%。\n\n業績不佳，Chanel 指出，是因為去 (2016) 年歐洲在法國恐怖攻擊頻傳，讓當地旅遊業疲軟、消費者購物慾望低迷；此外一部分原因為 Chanel 去年將旗下英國子公司 Chanel Limited UK 出售的緣故。\n\n時尚頭條網指出，2015 年開始， Chanel 就面臨業績挑戰，在 2015 年全年報， Chanel 營業利潤為 16 億美元，下滑 23%；總銷售額 62.4 億美元，下滑 17%。而占據大多利潤的化妝品跟香水，20105 年銷售額為 29.1 億美元，同比下滑 21%。報導指出，2015 年歐洲恐怖攻擊等安全問題的確讓歐洲奢侈品行業壟罩在陰影中，然而有分析師指出， Chanel 集團的獲利金雞母，化妝品跟香水業務下跌，就是該集團的警訊。\n\n北京商報報導，財富研究院院長周婷分析，消費者消費理念轉變很快，然而許多傳統的奢侈品品牌卻沒有跟上變革，老客戶流失的同時，新客戶進入速度也正在減緩，越是一線大牌業績下滑的速度就越快。過去幾年，部分奢侈品牌大舉擴張中國市場，門市覆蓋到一線、二線三線城市，然而快速擴張在某些程度上，等同損害品牌溢價跟稀有性。\n'

# %%
import glob

article_list = []

for file in glob.glob('./cnyes_data/*'):
    soup = BeautifulSoup(open(file).read(), 'html5lib')
    article_dict = {}
    article_dict['title']   = soup.select_one("main > h1 > span").text
    article_dict['dt']      = soup.select_one("main > h1 > div > time").text
    article_dict['content'] = soup.find('div', attrs={'itemprop': 'articleBody'}).text
    
    article_list.append(article_dict)

    
article_list
# Out:
# [{'content': '最近特斯拉 (Tesla) 執行長馬斯克與臉書執行長祖克柏之間為了人工智慧 (AI) 倒底是不是毀滅世界的濫觴而爭執不下。尚且不論您支持誰的說法，純粹看兩位科技界的大咖對於人工智慧的論點及評價，其實就很精彩。然而，不論是馬斯克認為人工智慧會威脅人類的生存，導致毀滅；還是祖克柏覺得人工智慧讓世界更好、讓人類更安全，其實都反映出人類對人工智慧既怕又愛的心情，也顯示面對未知世界，不變的還是人性的不安與恐懼。\n\n社會發展有其一定進程，隨著科技及人腦的不斷進步，過去從原始社會、到農業、工業再到二次工業革命，每每經歷一個時代的開端，總會有人擔心社會制度是否因此崩解，而開始倡議科技無用論。更切身點來說，就是擔心自己是否會因此失去工作，失去現有的一切，而開始抗拒，企圖阻止任何可能的新事物發生。\n\n人們對於自己無法掌握的事情都會產生疑慮。這點也是馬斯克所擔憂的，他認為，人工智慧的技術可能會超越人們對人工智慧應用範圍的想像，尤其是人工智慧的自動武器，很有可能被駭客入侵或電腦自行推演，導致失控。他和多位科技公司的投資者一起聯名向聯合國提出警語，希望馬上禁止國際間開發人工智慧的自動武器。不過，看起來引起的迴響似乎不大，因為各國仍舊持續研發相關武器。\n\n馬斯克提出的論調並不是沒有根據，他自己投資一家研究人工智慧的公司 OPEN AI，也不斷投入資源在研發自動車，對於人工智慧的運用有其看法。而過去幾部好萊塢電影「機械公敵」、「獵殺代理人」、「啟動機械碼」等內容，這種由人類設計發明出來的機器人最後回頭來殺人類的劇碼，似乎也都能勾起觀眾的共鳴。不過，大家倒底是嚮往這種世界，還是懼怕這種世界，可能還要再細分。\n\n英國《金融時報》專欄作家劉裘蒂就撰文表示，馬斯克和祖克柏的論戰，其實是涉及「人」和「機」之間的分野，虛擬世界與現實世界的邊界。兩人的爭論涉及他們所從事的商業活動，祖克柏的臉書就是在運用人工智慧技術，當然會說好；而馬斯可提出警語的目的只是在打響自己的品牌，並非真正想要拯救世界。但他們的言論同時間也正顯露出我們對於人工智慧的了解與認識仍存在有很多不足。\n\n也許就像原始人對火把既敬畏又恐懼一樣，人們對於人工智慧其實是存在著許多想像，因為想像所以產生圖像，但這圖像卻很模糊。今天祖克柏與馬斯克提出各自的想法，也各有擁護者，沒有對錯，當然也沒有輸贏。\
# ...

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(article_list, columns=['title', 'content', 'dt'])

# %%
df
# Out:
#                                       title  \
# 0                           【錢震宇專欄】AI是必經之惡？
# 1   〈三星新機發表〉經歷了去年的電池爆燃事件 三星今年的Note系列新機已不容有失
# 2                  港資丘鈦以12.47億元入股新鉅科案獲投審會放行
# 3                    【安聯投信】短線受市場影響 生技基本面仍穩健
# 4                  旺季到 印度股市平均漲幅上看雙位數 逢拉回可布局
# 5           〈三星新機發表〉台灣擠進Note8首波上市名單 就靠這些數字…
# 6              人民幣兌美元中間價24日報6.6525 創近11個月新高
# 7               惠譽：如果美國無法及時提高債務上限 AAA評級將有危險
# 8                              摩拜單車、ofo前進日本
# 9                  台新銀攜輔大 讓陸生來台唸書也能透過支付寶繳學費
# 10                               【西證國際】盤勢分析
# 11                   【大華銀投信】語不驚人死不休 川普威脅下走跌
# 12                台股早盤龍頭股氣勢足 大立光股價衝5825元再創高
# 13                          石四藥公佈2017年上半年業績
# 14                Facebook任命元老級高管統領所有消費硬件業務
# 15                    MLB／希爾9局完全比賽差一步反被敲再見轟
# 16               歐洲央行將辯論QE行動 德國明確表態：沒有延長的理由
# 17                  今年第一季 東京圈二手房成交量下降 但價格猛漲
# 18                            無人駕駛公車 在東京試運行
# 19                 法國恐攻太多 香奈兒好受傷 去年淨利潤跌掉35%
# ...

# %%
df.to_csv('cnyes.csv')

# %%
pd.read_csv('./cnyes.csv')
# Out:
#     Unnamed: 0                                    title  \
# 0            0                          【錢震宇專欄】AI是必經之惡？
# 1            1  〈三星新機發表〉經歷了去年的電池爆燃事件 三星今年的Note系列新機已不容有失
# 2            2                 港資丘鈦以12.47億元入股新鉅科案獲投審會放行
# 3            3                   【安聯投信】短線受市場影響 生技基本面仍穩健
# 4            4                 旺季到 印度股市平均漲幅上看雙位數 逢拉回可布局
# 5            5          〈三星新機發表〉台灣擠進Note8首波上市名單 就靠這些數字…
# 6            6             人民幣兌美元中間價24日報6.6525 創近11個月新高
# 7            7              惠譽：如果美國無法及時提高債務上限 AAA評級將有危險
# 8            8                             摩拜單車、ofo前進日本
# 9            9                 台新銀攜輔大 讓陸生來台唸書也能透過支付寶繳學費
# 10          10                               【西證國際】盤勢分析
# 11          11                   【大華銀投信】語不驚人死不休 川普威脅下走跌
# 12          12                台股早盤龍頭股氣勢足 大立光股價衝5825元再創高
# 13          13                          石四藥公佈2017年上半年業績
# 14          14                Facebook任命元老級高管統領所有消費硬件業務
# 15          15                    MLB／希爾9局完全比賽差一步反被敲再見轟
# ...

# %%
# tdcc
import requests as r

def str2dict(mystr):
    res_dict = {}
    for line in mystr.split('\n'):
        res_dict[line.split(":")[0]] = ":".join(line.split(":")[1:])
    return res_dict

URL = "https://www.tdcc.com.tw/smWeb/QryStock.jsp"

data_str = "SCA_DATE=20170818&SqlMethod=StockNo&StockNo=2330&StockName=&sub=%ACd%B8%DF"

headers_str = """Accept:text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
Accept-Encoding:gzip, deflate, br
Accept-Language:en-US,en;q=0.8
Cache-Control:no-cache
Connection:keep-alive
Content-Length:74
Content-Type:application/x-www-form-urlencoded
Cookie:JSESSIONID=0000dCJ2tClPKRLVrU0z048hXKM:19tmdfnom; _ga=GA1.3.1167120283.1503547259; _gid=GA1.3.1425075668.1503547259; _gat=1
Host:www.tdcc.com.tw
Origin:https://www.tdcc.com.tw
Pragma:no-cache
Referer:https://www.tdcc.com.tw/smWeb/QryStock.jsp
Upgrade-Insecure-Requests:1
User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.101 Safari/537.36"""

res = r.post(URL, data=data_str, headers=str2dict(headers_str))

# %%
res.text
# Out:
# '<!--\r\n程式名稱：QrySstock.jsp(股權分散表-SS04N)\r\n程式日期：N/A\r\n程式作者：950889\r\n表單編號：R140406\r\n首次簽入之Stream：SHAS_DEV1\\1 (950889) 2014-08-07 ： R140406(彈性面額)\r\n修改紀錄：\r\nISP_DEV1\\1 (950889) 2015-08-28 ： R150813(新增差異數欄位)\r\nISP_DEV1\\1 (950889) 2015-11-18 ： R151116(差異數欄位負數顯示)\r\nISP_DEV1\\1 (950889) 2015-11-30 ： R151127(欄位顯示)\r\nISP_DEV1\\1 (950889) 2015-01-05 ： R150821(證券簡稱放長)\r\nISP_DEV1\\1 (950889) 2016-05-19 ： C160529(增加EVOTE抽獎連結)\r\nISP_DEV1\\1 (950889) 2016-06-30 ： R160527(移除EVOTE抽獎連結)\r\nISP_DEV1\\1 (950889) 2016-06-29 ： R160603_股東常會電子投票公司資訊查詢\r\nISP_DEV1\\1 (950889) 2016-12-12 ： R161206_增加GA網站數據分析工具\r\nISP_DEV1\\1 (950889) 2017-06-12 ： R170412(移除EVOTE抽獎連結)\r\nISP_DEV1\\1 () 201X-XX-XX：RXXXXXX_移除OUT.PRINTLN 程式碼\r\n-->\r\n\r\n\r\n\r\n\r\n\r\n\r\n<html>\r\n<title>股務部資訊平台-集保戶股權分散表查詢</title>\r\n<meta http-equiv="Content-Type" content="text/html; charset=big5">\r\n<head>\r\n<script Language="JavaScript">\r\n<!--\r\n  function radioChg()\r\n  {\r\n     document.Qform.SqlMethod[0].checked=true
# ...

# %%
pd.read_html(res.text, attrs = {'class': 'mt'},)[1]
# Out:
#       0               1       2            3             4
# 0     序        持股/單位數分級     人 數      股 數/單位數  佔集保庫存數比例 (%)
# 1     1           1-999  144699     32069233          0.12
# 2     2       1000-5000  126861    262737671          1.01
# 3     3      5001-10000   22851    163813437          0.63
# 4     4     10001-15000    8745    106399530          0.41
# 5     5     15001-20000    4041     71012325          0.27
# 6     6     20001-30000    4532    110589108          0.42
# 7     7     30001-40000    2118     73252459          0.28
# 8     8     40001-50000    1357     60952057          0.23
# 9     9    50001-100000    2686    187354395          0.72
# 10   10   100001-200000    1499    209968590          0.80
# 11   11   200001-400000     981    276835201          1.06
# 12   12   400001-600000     446    217871686          0.84
# 13   13   600001-800000     248    170939944          0.65
# 14   14  800001-1000000     186    166520851          0.64
# ...

# %%
# Date time transformation
# Python datetime, default assumes OS timezone
# If your OS timezone is Asia/Taipei, the datetime module will prob just work
import datetime

datetime_str = "2017/08/24 10:01"

dt = datetime.datetime.strptime(datetime_str, "%Y/%m/%d %H:%M")
dt
# Out:
# datetime.datetime(2017, 8, 24, 10, 1)

# %%
type(dt)
# Out:
# datetime.datetime

# %%
dt.date()
# Out:
# datetime.date(2017, 8, 24)

# %%
dt.day
# Out:
# 24

# %%
dt.month
# Out:
# 8

# %%
# Because our OS is Asia/Taipei (UTC+8) timezoned.
# Python assumes OS timezone for timezone naive datetime objects
# Therefore our timestamp is correct
dt.timestamp()
# Out:
# 1503540060.0

# %%
# If our OS is on other timezone, like UTC
# we need to make our datetime object, timezone aware.
# datetime.datetime(day=,hour=,sec=, tzinfo='')

# %%
# Let's make a timezone first
# For example, Asia/Taipei (UTC+8)

# This represents, time difference with UTC
utc_8 = datetime.timedelta(hours=8)
utc_8
# Out:
# datetime.timedelta(0, 28800)

# %%
asia_taipei = datetime.timezone(utc_8)
asia_taipei
# Out:
# datetime.timezone(datetime.timedelta(0, 28800))

# %%
# Check again to see that our dt is timezone naive, aka no timezone info
dt
# Out:
# datetime.datetime(2017, 8, 24, 10, 1)

# %%
# use .replace() methods, to insert an attribute into datetime object
dt = dt.replace(tzinfo=asia_taipei)
dt
# Out:
# datetime.datetime(2017, 8, 24, 10, 1, tzinfo=datetime.timezone(datetime.timedelta(0, 28800)))

# %%
# Now, our dt object is datetime aware..
dt
# Out:
# datetime.datetime(2017, 8, 24, 10, 1, tzinfo=datetime.timezone(datetime.timedelta(0, 28800)))

# %%
# And the UTC timestamp will be correct
dt.timestamp()
# Out:
# 1503540060.0

# %%
# You also need to make this timezone aware
# If you are operating on a OS with different timezone than the data you are working on

dt_for_report = datetime.datetime.fromtimestamp(1503540060)
dt_for_report
# Out:
# datetime.datetime(2017, 8, 24, 10, 1)

# %%
# Transform datetime object to human readable time formatted string, 
dt_for_report.strftime("%Y-%b-%d %H:%M")
# Out:
# '2017-Aug-24 10:01'

# %%
# !pip install pytz

# %%
import pytz

# %%
asia_taipei = pytz.timezone('Asia/Taipei')
asia_taipei
# Out:
# <DstTzInfo 'Asia/Taipei' LMT+8:06:00 STD>

# %%
dt = datetime.datetime.now()
dt
# Out:
# datetime.datetime(2017, 8, 24, 14, 31, 46, 720215)

# %%
# First let's make our datetime timezone aware
dt = asia_taipei.localize(dt)

# %%
dt
# Out:
# datetime.datetime(2017, 8, 24, 14, 31, 46, 720215, tzinfo=<DstTzInfo 'Asia/Taipei' CST+8:00:00 STD>)

# %%
dt.astimezone(pytz.timezone("Asia/Tokyo"))
# Out:
# datetime.datetime(2017, 8, 24, 15, 31, 46, 720215, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>)

# %%
# Good alternate format for human and machine
dt.isoformat()
# Out:
# '2017-08-24T14:31:46.720215+08:00'

# %%
# Other useful python datetime libs
# !pip install pendulum # https://pendulum.eustace.io/
# !pip install arrow # http://arrow.readthedocs.io/en/latest/#quickstart
# Out:
# ...
#     100% |████████████████████████████████| 112kB 645kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 471kB 752kB/s ta 0:00:01
# ...
#   Running setup.py install for tzlocal ... done
# ...
#   Using cached arrow-0.10.0.tar.gz
# ...
#   Running setup.py install for arrow ... done
# ...

# %%
# !pip install python-dateutil

# %%
import dateutil

# %%
dateutil.parser.parse('2017-08-24T14:31:46.720215+08:00')
# Out:
# datetime.datetime(2017, 8, 24, 14, 31, 46, 720215, tzinfo=tzoffset(None, 28800))

# %%
dateutil.parser.parse('2017/08/24 10:01')
# Out:
# datetime.datetime(2017, 8, 24, 10, 1)

# %%
# 科技產業資訊室
import requests as r
from bs4 import BeautifulSoup

headers_str = """Accept:*/*
Accept-Encoding:gzip, deflate
Accept-Language:en-US,en;q=0.8
Cache-Control:no-cache
Connection:keep-alive
Cookie:ASP.NET_SessionId=okbqinfxbgkbgkbqzoqofgys; _gat=1; _ga=GA1.3.1968382673.1503558295; _gid=GA1.3.1636708801.1503558295
Host:iknow.stpi.narl.org.tw
Pragma:no-cache
Referer:http://iknow.stpi.narl.org.tw/Post/News.aspx
User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.101 Safari/537.36
X-Requested-With:XMLHttpRequest"""

URL = 'http://iknow.stpi.narl.org.tw/Post/moreNew.aspx?Type=ALL&year=0&month=0&keyword=&mode=0'

res = r.get(URL, headers=str2dict(headers_str))

# %%
[link['href'] for link in BeautifulSoup(res.text, 'html5lib').select('li > a')]
# Out:
# ['https://udn.com/news/story/7240/2654630',
#  'https://udn.com/news/story/7240/2654192',
#  'https://udn.com/news/story/7241/2653669',
#  'http://zh.cn.nikkei.com/politicsaeconomy/investtrade/26654-2017-08-23-09-16-16.html',
#  'http://www.fpdisplay.com/news/2017-08/info-184938-153.htm',
#  'https://udn.com/news/story/7238/2651754',
#  'https://udn.com/news/story/7240/2651249',
#  'https://udn.com/news/story/7240/2651244',
#  'http://www.fpdisplay.com/news/2017-08/info-184908-689.htm',
#  'https://udn.com/news/story/7240/2650303',
#  'https://udn.com/news/story/7240/2658389',
#  'https://udn.com/news/story/7240/2658373',
#  'https://udn.com/news/story/7240/2658535',
#  'https://udn.com/news/story/7238/2657554',
#  'https://udn.com/news/story/7240/2658121',
#  'http://www.chinatimes.com/realtimenews/20170822002397-260412',
#  'http://www.fpdisplay.com/news/2017-08/info-184944-058.htm',
#  'https://udn.com/news/story/7240/2656271',
#  'https://udn.com/news/story/7240/2656349',
# ...

# %%
# 3D printing social analysis
import requests as r

URL = "https://graph.facebook.com/v2.10/1068531466501015/feed?fields=comments.limit(500),message&limit=500&access_token=EAACEdEose0cBADtmo8ZCI33ho2UK1OxjlzWsoytndyVqrjSnBusb6oT8uv36JZBL5DVYoQNZAzDgBKcrt1ZC7OMCskP44ZAd9DTk1EaWk2U9LHiwRlMxkPqkjJdpdu5kZCUqD7BuMkVJbIZBm9OLtFDOWr5ERxMwXk96AO8jsqWVAYd8s4phcaIeezldEdkuwIZD"

res = r.get(URL)

# %%
res.json().keys()
# Out:
# dict_keys(['data', 'paging'])

# %%
res.json()['paging']
# Out:
# {'next': 'https://graph.facebook.com/v2.10/1068531466501015/feed?fields=comments.limit%28500%29,message&limit=500&icon_size=16&access_token=EAACEdEose0cBADtmo8ZCI33ho2UK1OxjlzWsoytndyVqrjSnBusb6oT8uv36JZBL5DVYoQNZAzDgBKcrt1ZC7OMCskP44ZAd9DTk1EaWk2U9LHiwRlMxkPqkjJdpdu5kZCUqD7BuMkVJbIZBm9OLtFDOWr5ERxMwXk96AO8jsqWVAYd8s4phcaIeezldEdkuwIZD&until=1503349344&__paging_token=enc_AdABfFoITuBoV5T4RZAZAfqKp5I6qaC8AyzvsXpJgpB5d5DE7q3oqpBzpSHuZByZC0aS7nb3gQDwG9ztg1ZBRVuOi5tKymj5HAInkgWZCSkBJJUjRNlgZDZD',
# ...

# %%
res.json()['data'][1]
# Out:
# {'comments': {'data': [{'created_time': '2017-08-24T07:21:10+0000',
#     'from': {'id': '10155321523560080', 'name': 'Engin Dikmen'},
#     'id': '1560358307318326',
#     'message': 'dont forget to adjust your probe :) (been there done that)'}],
#   'paging': {'cursors': {'after': 'WTI5dGJXVnVkRjlqZAFhKemIzSTZANVFUyTURNMU9ETXdOek14T0RNeU5qb3hOVEF6TlRVNU1qY3gZD',
#     'before': 'WTI5dGJXVnVkRjlqZAFhKemIzSTZANVFUyTURNMU9ETXdOek14T0RNeU5qb3hOVEF6TlRVNU1qY3gZD'}}},
#  'id': '1068531466501015_1560353817318775',
#  'message': "Soooo what can go wrong? Guess I'll find out tonight"}

# %%
with open('./3d_printing.json', 'w') as f:
    f.write(res.text)

# %%
# https://docs.python.org/3/library/re.html

import re

# %%
len(res.text)
# Out:
# 1049606

# %%
re.search('(https:\\\/\\\/www.thing.*)', res.text)[1]
# Out:
# 'https:\\/\\/www.thingiverse.com\\/thing:2172490","id":"1559947350692755"},{"created_time":"2017-08-23T20:12:43+0000","from":{"name":"Jelle Posthuma","id":"10205055662895229"},"message":"3DTouch \\/ BLTouch","id":"1559956344025189"},{"created_time":"2017-08-23T20:35:15+0000","from":{"name":"Benjamin Fahl","id":"1230532550296283"},"message":"ABL IR Sensor work on glass, FR4, Paper, Catalog","id":"1559969810690509"},{"created_time":"2017-08-23T21:14:53+0000","from":{"name":"Corey Pinassi","id":"10152854704946271"},"message":"Deffo bl touch","id":"1559999354020888"},{"created_time":"2017-08-23T21:27:22+0000","from":{"name":"Wenceslao Posada","id":"10203847325291777"},"message":"Why all this hype with the BL touch? It does not have any advantage compared to the $5 PIBOT sensor (except if you use black bed)","id":"1560006130686877"},{"created_time":"2017-08-23T21:33:37+0000","from":{"name":"Ben Draper","id":"652979838221231"},"message":"I\'ve tried basically every variation of auto leveli
# ...

# %%
mystr = """'https:\\/\\/www.thingiverse.com\\/thing:2172490","id":"1559947350692755"},{"created_time":"2017-08-23T20:12:43+0000","from":{"name":"Jelle Posthuma","id":"10205055662895229"},"message":"3DTouch \\/ BLTouch","id":"1559956344025189"},{"created_time":"2017-08-23T20:35:15+0000","from":{"name":"Benjamin Fahl","id":"1230532550296283"},"message":"ABL IR Sensor work on glass, FR4, Paper, Catalog","id":"1559969810690509"},{"created_time":"2017-08-23T21:14:53+0000","from":{"name":"Corey Pinassi","id":"10152854704946271"},"message":"Deffo bl touch","id":"1559999354020888"},{"created_time":"2017-08-23T21:27:22+0000","from":{"name":"Wenceslao Posada","id":"10203847325291777"},"message":"Why all this hype with the BL touch? It does not have any advantage compared to the $5 PIBOT sensor (except if you use black bed)","id":"1560006130686877"},{"created_time":"2017-08-23T21:33:37+0000","from":{"name":"Ben Draper","id":"652979838221231"},"message":"I\'ve tried basically every variation of auto leveling sensors and highly reccomend BLTouch","id":"1560009864019837"},{"created_time":"2017-08-23T21:42:25+0000","from":{"name":"Lance Gropper","id":"910483142308866"}"""
mystr
# Out:
# '\'https:\\/\\/www.thingiverse.com\\/thing:2172490","id":"1559947350692755"},{"created_time":"2017-08-23T20:12:43+0000","from":{"name":"Jelle Posthuma","id":"10205055662895229"},"message":"3DTouch \\/ BLTouch","id":"1559956344025189"},{"created_time":"2017-08-23T20:35:15+0000","from":{"name":"Benjamin Fahl","id":"1230532550296283"},"message":"ABL IR Sensor work on glass, FR4, Paper, Catalog","id":"1559969810690509"},{"created_time":"2017-08-23T21:14:53+0000","from":{"name":"Corey Pinassi","id":"10152854704946271"},"message":"Deffo bl touch","id":"1559999354020888"},{"created_time":"2017-08-23T21:27:22+0000","from":{"name":"Wenceslao Posada","id":"10203847325291777"},"message":"Why all this hype with the BL touch? It does not have any advantage compared to the $5 PIBOT sensor (except if you use black bed)","id":"1560006130686877"},{"created_time":"2017-08-23T21:33:37+0000","from":{"name":"Ben Draper","id":"652979838221231"},"message":"I\'ve tried basically every variation of auto leve
# ...

# %%
# Find all https:\\/\\/www.thingiverse.com\\/thing:2172490 in result
re.findall('https:\\\/\\\/www.thingiverse.com\\\/thing:2172490', res.text)
# Out:
# ['https:\\/\\/www.thingiverse.com\\/thing:2172490',
#  'https:\\/\\/www.thingiverse.com\\/thing:2172490']

# %%
# Let's repalce 2172490, to placeholder for numbers
# in RegEx, \d => 0-9
re.findall('https:\\\/\\\/www.thingiverse.com\\\/thing:\d\d\d\d\d\d\d', res.text)
# Out:
# ['https:\\/\\/www.thingiverse.com\\/thing:2172490',
#  'https:\\/\\/www.thingiverse.com\\/thing:1875141',
#  'https:\\/\\/www.thingiverse.com\\/thing:2392856',
#  'https:\\/\\/www.thingiverse.com\\/thing:2320216',
#  'https:\\/\\/www.thingiverse.com\\/thing:2103748',
#  'https:\\/\\/www.thingiverse.com\\/thing:2350184',
#  'https:\\/\\/www.thingiverse.com\\/thing:2055665',
#  'https:\\/\\/www.thingiverse.com\\/thing:2040512',
#  'https:\\/\\/www.thingiverse.com\\/thing:2144338',
#  'https:\\/\\/www.thingiverse.com\\/thing:2268827',
#  'https:\\/\\/www.thingiverse.com\\/thing:2091529',
#  'https:\\/\\/www.thingiverse.com\\/thing:2216161',
#  'https:\\/\\/www.thingiverse.com\\/thing:1672959',
#  'https:\\/\\/www.thingiverse.com\\/thing:2256538',
#  'https:\\/\\/www.thingiverse.com\\/thing:1852358',
#  'https:\\/\\/www.thingiverse.com\\/thing:2055499',
#  'https:\\/\\/www.thingiverse.com\\/thing:2322901',
#  'https:\\/\\/www.thingiverse.com\\/thing:2471089',
# ...

# %%
# Let's repalce 2172490, to placeholder for digits
# in RegEx, \d => 0-9
# Let's make number of digits a range, e.g. 1 to N digits after thing: 
# \d{1} => \d
# \d{2} => \d\d
# \d{3} => \d\d\d
# It can also be a range
# \d{1,3} => \d to \d\d\d
# \d{1,} => \d to N * \d
re.findall('https:\\\/\\\/www.thingiverse.com\\\/thing:\d{1,}', res.text)
# Out:
# ['https:\\/\\/www.thingiverse.com\\/thing:2172490',
#  'https:\\/\\/www.thingiverse.com\\/thing:1875141',
#  'https:\\/\\/www.thingiverse.com\\/thing:597043',
#  'https:\\/\\/www.thingiverse.com\\/thing:2392856',
#  'https:\\/\\/www.thingiverse.com\\/thing:911891',
#  'https:\\/\\/www.thingiverse.com\\/thing:2320216',
#  'https:\\/\\/www.thingiverse.com\\/thing:2103748',
#  'https:\\/\\/www.thingiverse.com\\/thing:2350184',
#  'https:\\/\\/www.thingiverse.com\\/thing:397575',
#  'https:\\/\\/www.thingiverse.com\\/thing:2055665',
#  'https:\\/\\/www.thingiverse.com\\/thing:2040512',
#  'https:\\/\\/www.thingiverse.com\\/thing:238435',
#  'https:\\/\\/www.thingiverse.com\\/thing:2144338',
#  'https:\\/\\/www.thingiverse.com\\/thing:2268827',
#  'https:\\/\\/www.thingiverse.com\\/thing:2091529',
#  'https:\\/\\/www.thingiverse.com\\/thing:2216161',
#  'https:\\/\\/www.thingiverse.com\\/thing:1672959',
#  'https:\\/\\/www.thingiverse.com\\/thing:2256538',
# ...

# %%
# \w => [a-zA-Z0-9]

test_email = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

hihi

is also a cool mail"""

re.findall('ian@gmail.com', test_email)
# Out:
# ['ian@gmail.com']

# %%
# \w => [a-zA-Z0-9]

test_email = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

hihi

is also a cool mail"""

re.findall('\w\w\w@gmail.com', test_email)
# Out:
# ['ian@gmail.com']

# %%
# \w => [a-zA-Z0-9]
# email has 1 to N alphanumeric characters before @

test_email = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

hihi

is also a cool mail"""

re.findall('\w{1,}@gmail.com', test_email)
# Out:
# ['ian@gmail.com']

# %%
# \w => [a-zA-Z0-9]
# + => {1,}

test_email = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

hihi

is also a cool mail"""

re.findall('\w+@gmail.com', test_email)
# Out:
# ['ian@gmail.com']

# %%
# \w => [a-zA-Z0-9]
# Email, also has alphanumeric chars after @
# Wait, also .

test_email = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

hihi

is also a cool mail"""

re.findall('\w+@\w+', test_email)
# Out:
# ['ian@gmail', 'ianchen@3dprinting']

# %%
# \w => [a-zA-Z0-9]
# [] => mix multiple patterns
# [\w.]

test_email = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

hi ianchen@ask.3dprinting.com hi

is also a cool mail"""

re.findall('\w+@[\w.]+', test_email)
# Out:
# ['ian@gmail.com', 'ianchen@3dprinting.com', 'ianchen@ask.3dprinting.com']

# %%
re.findall('\w+@[\w.]+', res.text)
# Out:
# []

# %%
# ? => make previous char 0 or 1

test_url = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

http://news.cnyes.com/news/id/3900613

:D :D :D

https://pypi.python.org/pypi/pytz
http://pypi.python.org/pypi/pytz

I like baseball

http://www.ebay.com/itm/12V-280W-Silicone-Heatbed-Heat-Bed-Hot-Plate-For-3D-Printer-Prusa-Mendel-/261994359926?var&hash=item3d0014ac76%3Am%3AmcllPF7PJg92wZMaNc_1K9g

hi ianchen@ask.3dprinting.com hi

https://goo.gl/pKvK5R 

is also a cool mail"""

re.findall('https?://pypi.python.org/pypi/pytz', test_url)
# Out:
# ['https://pypi.python.org/pypi/pytz', 'http://pypi.python.org/pypi/pytz']

# %%
# ? => make previous char 0 or 1

test_url = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

http://news.cnyes.com/news/id/3900613

:D :D :D

https://pypi.python.org/pypi/pytz
http://pypi.python.org/pypi/pytz

https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx?asq=u2qcKLxwzRU5NDuxJ0kOF3T91go8JoYYMxAgy8FkBH1BN0lGAtYH25sdXoy34qb9xpuyEnZSDI87xf5QnWTKS7qgfrWr5nC5BM9mtPbpK0Y38mt%2FjN%2BVnnPoOZs2pSw%2FziYTEgCWZvezHiPT5fcUM41vXGtuywoUoaiplWNdnsV9hkMbE2S2h8huqN6Va0gamezZfUbWhSrecUXUsImpkA%3D%3D&city=3435&tick=636391606521&isdym=true&searchterm=Sapporo%2C%20Japan&txtuuid=3107dcef-ec5c-452d-a681-84a043d9fb4b&pagetypeid=1&origin=TW&cid=-1&tag=&gclid=&aid=130243&userId=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8&languageId=1&sessionId=pmfnpqlgzwwhftausi1uzc3w&storefrontId=3&currencyCode=TWD&htmlLanguage=en-us&trafficType=User&cultureInfoName=en-US&textToSearch=Sapporo%2C%20Japan&guid=3107dcef-ec5c-452d-a681-84a043d9fb4b&checkIn=2018-01-12&checkOut=2018-01-22&los=10&rooms=1&adults=4&children=0&childages=&priceCur=TWD&hotelReviewScore=5&ckuid=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8

I like baseball

http://www.ebay.com/itm/12V-280W-Silicone-Heatbed-Heat-Bed-Hot-Plate-For-3D-Printer-Prusa-Mendel-/261994359926?var&hash=item3d0014ac76%3Am%3AmcllPF7PJg92wZMaNc_1K9g

hi ianchen@ask.3dprinting.com hi

https://goo.gl/pKvK5R 

is also a cool mail"""

re.findall('https?://[\w./-]+', test_url)
# Out:
# ['http://news.cnyes.com/news/id/3900613',
#  'https://pypi.python.org/pypi/pytz',
#  'http://pypi.python.org/pypi/pytz',
#  'https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx',
#  'http://www.ebay.com/itm/12V-280W-Silicone-Heatbed-Heat-Bed-Hot-Plate-For-3D-Printer-Prusa-Mendel-/261994359926',
#  'https://goo.gl/pKvK5R']

# %%
# ? => make previous char 0 or 1

test_url = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

http://news.cnyes.com/news/id/3900613

:D :D :D

https://pypi.python.org/pypi/pytz
http://pypi.python.org/pypi/pytz

https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx?asq=u2qcKLxwzRU5NDuxJ0kOF3T91go8JoYYMxAgy8FkBH1BN0lGAtYH25sdXoy34qb9xpuyEnZSDI87xf5QnWTKS7qgfrWr5nC5BM9mtPbpK0Y38mt%2FjN%2BVnnPoOZs2pSw%2FziYTEgCWZvezHiPT5fcUM41vXGtuywoUoaiplWNdnsV9hkMbE2S2h8huqN6Va0gamezZfUbWhSrecUXUsImpkA%3D%3D&city=3435&tick=636391606521&isdym=true&searchterm=Sapporo%2C%20Japan&txtuuid=3107dcef-ec5c-452d-a681-84a043d9fb4b&pagetypeid=1&origin=TW&cid=-1&tag=&gclid=&aid=130243&userId=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8&languageId=1&sessionId=pmfnpqlgzwwhftausi1uzc3w&storefrontId=3&currencyCode=TWD&htmlLanguage=en-us&trafficType=User&cultureInfoName=en-US&textToSearch=Sapporo%2C%20Japan&guid=3107dcef-ec5c-452d-a681-84a043d9fb4b&checkIn=2018-01-12&checkOut=2018-01-22&los=10&rooms=1&adults=4&children=0&childages=&priceCur=TWD&hotelReviewScore=5&ckuid=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8

I like baseball

http://www.ebay.com/itm/12V-280W-Silicone-Heatbed-Heat-Bed-Hot-Plate-For-3D-Printer-Prusa-Mendel-/261994359926?var&hash=item3d0014ac76%3Am%3AmcllPF7PJg92wZMaNc_1K9g

hi ianchen@ask.3dprinting.com hi

https://goo.gl/pKvK5R 

is also a cool mail"""

re.findall('https?://[\w./-?&%]+', test_url)
# Out:
# ['http://news.cnyes.com/news/id/3900613',
#  'https://pypi.python.org/pypi/pytz',
#  'http://pypi.python.org/pypi/pytz',
#  'https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx?asq=u2qcKLxwzRU5NDuxJ0kOF3T91go8JoYYMxAgy8FkBH1BN0lGAtYH25sdXoy34qb9xpuyEnZSDI87xf5QnWTKS7qgfrWr5nC5BM9mtPbpK0Y38mt%2FjN%2BVnnPoOZs2pSw%2FziYTEgCWZvezHiPT5fcUM41vXGtuywoUoaiplWNdnsV9hkMbE2S2h8huqN6Va0gamezZfUbWhSrecUXUsImpkA%3D%3D&city=3435&tick=636391606521&isdym=true&searchterm=Sapporo%2C%20Japan&txtuuid=3107dcef',
#  'http://www.ebay.com/itm/12V',
#  'https://goo.gl/pKvK5R']

# %%
# ? => make previous char 0 or 1

test_url = """Hello all, ian@gmail.com is a cool email adddress, email me :D ;D
ianchen@3dprinting.com

http://news.cnyes.com/news/id/3900613

:D :D :D

https://pypi.python.org/pypi/pytz
http://pypi.python.org/pypi/pytz

https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx?asq=u2qcKLxwzRU5NDuxJ0kOF3T91go8JoYYMxAgy8FkBH1BN0lGAtYH25sdXoy34qb9xpuyEnZSDI87xf5QnWTKS7qgfrWr5nC5BM9mtPbpK0Y38mt%2FjN%2BVnnPoOZs2pSw%2FziYTEgCWZvezHiPT5fcUM41vXGtuywoUoaiplWNdnsV9hkMbE2S2h8huqN6Va0gamezZfUbWhSrecUXUsImpkA%3D%3D&city=3435&tick=636391606521&isdym=true&searchterm=Sapporo%2C%20Japan&txtuuid=3107dcef-ec5c-452d-a681-84a043d9fb4b&pagetypeid=1&origin=TW&cid=-1&tag=&gclid=&aid=130243&userId=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8&languageId=1&sessionId=pmfnpqlgzwwhftausi1uzc3w&storefrontId=3&currencyCode=TWD&htmlLanguage=en-us&trafficType=User&cultureInfoName=en-US&textToSearch=Sapporo%2C%20Japan&guid=3107dcef-ec5c-452d-a681-84a043d9fb4b&checkIn=2018-01-12&checkOut=2018-01-22&los=10&rooms=1&adults=4&children=0&childages=&priceCur=TWD&hotelReviewScore=5&ckuid=6c681a7b-1d63-4a2a-bd08-2ca0d96baec8

I like baseball

http://www.ebay.com/itm/12V-280W-Silicone-Heatbed-Heat-Bed-Hot-Plate-For-3D-Printer-Prusa-Mendel-/261994359926?var&hash=item3d0014ac76%3Am%3AmcllPF7PJg92wZMaNc_1K9g

hi ianchen@ask.3dprinting.com hi

https://goo.gl/pKvK5R 

is also a cool mail"""

re.findall('https?://.+', test_url)
# Out:
# ['http://news.cnyes.com/news/id/3900613',
#  'https://pypi.python.org/pypi/pytz',
#  'http://pypi.python.org/pypi/pytz',
# ...

# %%
re.findall("""https?:\\\/\\\/[\w$-_.+!*'(),]+""", res.text)
# Out:
# ['https:\\/\\/tinyurl.com\\/ybjr85bu',
#  'https:\\/\\/m.aliexpress.com\\/s\\/item\\/32761924885.html?spm=a2g0n.search-cache.0.0.7f25570f2s4nKX',
#  'https:\\/\\/www.amazon.ca\\/gp\\/product\\/B00542U3M4\\/ref=oh_aui_detailpage_o03_s00?ie=UTF8&psc=1',
#  'https:\\/\\/www.youtube.com\\/watch?v=XeYJkzrrM3Q',
#  'https:\\/\\/goo.gl\\/pKvK5R',
#  'https:\\/\\/goo.gl\\/y9mhKV\\n-',
#  'https:\\/\\/goo.gl\\/kXA7dV\\n\\nThe',
#  'https:\\/\\/goo.gl\\/N5VzoD',
#  'https:\\/\\/youtu.be\\/HdLyox9N8CE',
#  'https:\\/\\/www.thingiverse.com\\/thing:2172490',
#  'https:\\/\\/medium.com\\/\\u0040szymondudzik\\/anet-a8-compendium-b82c57703513',
# ...

# %%
# Regex exercise, find all IP address

import re

ptt_html = """<!DOCTYPE html>
<html>
	<head>
		<meta charset="utf-8">
		

<meta name="viewport" content="width=device-width, initial-scale=1">

<title>[問卦] 排球是不是比棒球刺激？ - 看板 Gossiping - 批踢踢實業坊</title>
<meta name="robots" content="all">
<meta name="keywords" content="Ptt BBS 批踢踢">
<meta name="description" content="每次看排球
看到選手跟很高殺球 殺到對手擋不住
或是原本很驚險的球 隊友都可連續救回
覺得超燃 超刺激
真的覺得比棒球還好看
">
<meta property="og:site_name" content="Ptt 批踢踢實業坊">
<meta property="og:title" content="[問卦] 排球是不是比棒球刺激？">
<meta property="og:description" content="每次看排球
看到選手跟很高殺球 殺到對手擋不住
或是原本很驚險的球 隊友都可連續救回
覺得超燃 超刺激
真的覺得比棒球還好看
">
<link rel="canonical" href="https://www.ptt.cc/bbs/Gossiping/M.1503561663.A.A47.html">

<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-common.css">
<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen">
<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-custom.css">
<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen">
<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print">




	</head>
    <body>
		
<div id="fb-root"></div>
<script>(function(d, s, id) {
var js, fjs = d.getElementsByTagName(s)[0];
if (d.getElementById(id)) return;
js = d.createElement(s); js.id = id;
js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
fjs.parentNode.insertBefore(js, fjs);
}(document, 'script', 'facebook-jssdk'));</script>

<div id="topbar-container">
	<div id="topbar" class="bbs-content">
		<a id="logo" href="/">批踢踢實業坊</a>
		<span>&rsaquo;</span>
		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
		<a class="right small" href="/about.html">關於我們</a>
		<a class="right small" href="/contact.html">聯絡資訊</a>
	</div>
</div>
<div id="navigation-container">
	<div id="navigation" class="bbs-content">
		<a class="board" href="/bbs/Gossiping/index.html">返回看板</a>
		<div class="bar"></div>
		<div class="share">
			<span>分享</span>
			<div class="fb-like" data-send="false" data-layout="button_count" data-width="90" data-show-faces="false" data-href="http://www.ptt.cc/bbs/Gossiping/M.1503561663.A.A47.html"></div>

			<div class="g-plusone" data-size="medium"></div>
<script type="text/javascript">
window.___gcfg = {lang: 'zh-TW'};
(function() {
var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
po.src = 'https://apis.google.com/js/plusone.js';
var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
})();
</script>

		</div>
	</div>
</div>
<div id="main-container">
    <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">xdfunnyboy (XD大叔)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Gossiping</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[問卦] 排球是不是比棒球刺激？</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Thu Aug 24 16:01:01 2017</span></div>
每次看排球

看到選手跟很高殺球 殺到對手擋不住

或是原本很驚險的球 隊友都可連續救回

覺得超燃 超刺激

真的覺得比棒球還好看


有沒有排球比棒球好看的八卦

--
<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 59.115.93.9
</span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/Gossiping/M.1503561663.A.A47.html" target="_blank" rel="nofollow">https://www.ptt.cc/bbs/Gossiping/M.1503561663.A.A47.html</a>
</span><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Rrrxddd</span><span class="f3 push-content">: 甲</span><span class="push-ipdatetime"> 08/24 16:01
</span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">pinhanpaul</span><span class="f3 push-content">: 有一個用臉接球的</span><span class="push-ipdatetime"> 08/24 16:01
</span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">cake10414</span><span class="f3 push-content">: 4</span><span class="push-ipdatetime"> 08/24 16:01
</span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rickey1270</span><span class="f3 push-content">: 有</span><span class="push-ipdatetime"> 08/24 16:01
</span></div></div>
    
    <div id="article-polling" data-pollurl="/poll/Gossiping/M.1503561663.A.A47.html?cacheKey=2052-44010501&offset=794&offset-sig=1242d78bd066fd537f8a96ddf4043dbf610e2bb9" data-longpollurl="/v1/longpoll?id=d1ffea86372141cbbd4616c0df4c6e5e8991f755" data-offset="794"></div>
    

    
<div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>

</div>

		

<script>
  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
  })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');

  ga('create', 'UA-32365737-1', {
    cookieDomain: 'ptt.cc',
    legacyCookieDomain: 'ptt.cc'
  });
  ga('send', 'pageview');
</script>


		
<script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
<script src="//images.ptt.cc/bbs/v2.22/bbs.js"></script>

    </body>
</html>"""

author_ip = ''
