# %%
import requests

url = 'http://relive.tw/'

resp = requests.get(url)

# %%
resp.text
# Out:
# '<!DOCTYPE html>\r\n<!--[if IE 7 | IE 8]>\r\n<html class="ie" lang="zh-TW" prefix="og: http://ogp.me/ns#">\r\n<![endif]-->\r\n<!--[if !(IE 7) | !(IE 8)  ]><!-->\r\n<html lang="zh-TW" prefix="og: http://ogp.me/ns#" class="no-js">\r\n<!--<![endif]-->\r\n<head>\r\n\t<meta charset="UTF-8">\r\n\t<meta name="robots" content="all" />\r\n\t<meta name="author" content="吱吱復健" />\r\n\t<meta name="rating" content="general" />\r\n\t<meta name="viewport" content="width=device-width">\r\n\t<link rel="profile" href="http://gmpg.org/xfn/11">\r\n\t<link rel="alternate" title="RSS 2.0 訂閱最新文章" href="http://relive.tw/feed/" />\r\n\t<link rel="pingback" href="http://relive.tw/xmlrpc.php">\r\n\t<!--[if lt IE 9]>\r\n\t<script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>\r\n\t<![endif]-->\r\n\t<title>吱吱復健 - 職能治療增添美好生活</title>\n\n<!-- This site is optimized with the Yoast SEO plugin v5.2 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="職能治療增添美好生活"/>\n<link rel
# ...

# %%
import re

# %%
d_list = [row.split(',')[-3].strip("'") for row in re.findall('''cat1\.a\((.+)\);''', resp.text)]

# %%
[url for url in d_list if not url.startswith('cate') and url]
# Out:
# ['stroke-stretch-muscle/',
#  'ot-long-term-care/',
#  'stroke-motor-rehab/',
#  'stroke-pac/',
#  'sleep-after-stroke/',
#  'sensory-reeducation/',
#  'neuroplasticity/',
#  'stroke-stand-up/',
#  'stroke-dressing/',
#  'dementia-ng-interaction/',
#  'stroke-sitting-balance/',
#  'dementia-delusion/',
#  'stroke-edema/',
#  'how-to-reduce-the-muscle-tone/',
#  'shipai-accessibility/',
#  'stroke-motor-rehabilitation/',
#  'mental-practice/',
#  'constraint-induced-movement-therapy/',
#  'stroke-rehab-clinic-hospitalized/',
#  'taiwan-occupational-therapy-clinic/',
#  'pediatric-occupational-therapy-facebook/',
#  'edema/',
#  'how-to-mirror-therapy/',
#  'bilateral-arm-training-stroke/',
#  'stroke-question/',
#  'dementia-rehab/',
#  'occupational-therapy-stroke-rehabilitation/',
#  'control-someone-arm-with-your-brain/',
#  'de-quervains-syndrome/',
#  'muscle-tone/',
#  'child-hug/',
#  'robot-assisted-therapy-stroke/',
#  'attention-calling/',
# ...
